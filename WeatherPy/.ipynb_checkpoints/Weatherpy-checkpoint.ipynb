# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_csv = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country.upper())

# Print the city count to confirm sufficient count
print(len(cities))
#print the country count to confirm match
print(len(countries))
# Out:
# 640
# 640

# %%
#create dataframe
ctweather_df = pd.DataFrame({'City': cities, 'Cloudiness': "", 'Country':countries, 'Date': "", 
                             'Humidity': "", 'Lat': "", 'Lng': "", 'Max Temp': "", 'Windspeed': ""})
ctweather_df.head()
# Out:
#             City Cloudiness Country Date Humidity Lat Lng Max Temp Windspeed
# 0   quatre cocos                 MU
# 1     butaritari                 KI
# 2         narsaq                 GL
# 3    tuktoyaktuk                 CA
# 4  belushya guba                 RU

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#keep track of response 
response_num = 1
response_set = 1

#api call
api_url = 'https://api.openweathermap.org/data/2.5/weather?units=imperial&q='

#run call
print('''------------------
      Beginning Data Retrieval
      ---------------------\n''')
for index, row in ctweather_df.iterrows():
    #call url
    #based on example call url 
    call_url = api_url + row['City']+','+ '&appid=' + weather_api_key
    #call
    response = requests.get(call_url).json()
    #exception 
    try: 
        #print message
        print(f'Processing Weather Data for Response {response_num} of Set {response_set} | {response["name"]}')
        #input data into DF
        ctweather_df.loc[index, 'Cloudiness']= response['clouds']['all']
        ctweather_df.loc[index, 'Date']= response['dt']
        ctweather_df.loc[index, 'Humidity']= response['main']['humidity']
        ctweather_df.loc[index, 'Lat']= response['coord']['lat']
        ctweather_df.loc[index, 'Lng']= response['coord']['lon']
        ctweather_df.loc[index, 'Max Temp']= response['main']['temp_max']
        ctweather_df.loc[index, 'Windspeed']= response['wind']['speed']
        #increase response count
        response_num += 1
    except (KeyError, IndexError):
              print("City not Found------SKIP")
    #api call limiter to 
    if response_num == 51:
       response_set += 1
       response_num = 1
       time.sleep(60)
print('''--------------------
         Data Retrieval Finished
         -------------------- ''')
# Out:
# ------------------
#       Beginning Data Retrieval
#       ---------------------
#
# Processing Weather Data for Response 1 of Set 1 | Quatre Cocos
# Processing Weather Data for Response 2 of Set 1 | Butaritari
# Processing Weather Data for Response 3 of Set 1 | Narsaq
# Processing Weather Data for Response 4 of Set 1 | Tuktoyaktuk
# City not Found------SKIP
# Processing Weather Data for Response 5 of Set 1 | Clyde River
# City not Found------SKIP
# Processing Weather Data for Response 6 of Set 1 | Dikson
# Processing Weather Data for Response 7 of Set 1 | Leninskoye
# Processing Weather Data for Response 8 of Set 1 | Cascais
# City not Found------SKIP
# Processing Weather Data for Response 9 of Set 1 | Leningradskiy
# Processing Weather Data for Response 10 of Set 1 | Bambous Virieux
# Processing Weather Data for Response 11 of Set 1 | Busselton
# Processing Weather Data for Response 12 of Set 1 | Caserta
# Processing Weather Data for Response 13 of Set 1 | Ushuaia
# Processing Weather Data for Response 14 of Set 1 | Namatanai
# City not Found------SKIP
# Processing Weather Data for Response 15 of Set 1 | Klaksvík
# Processing Weather Data for Response 16 of Set 1 | Kharp
# City not Found------SKIP
# Processing Weather Data for Response 17 of Set 1 | Juegang
# Processing Weather Data for Response 18 of Set 1 | San Cristobal
# Processing Weather Data for Response 19 of Set 1 | Hilo
# Processing Weather Data for Response 20 of Set 1 | Punta Arenas
# Processing Weather Data for Response 21 of Set 1 | Arraial do Cabo
# Processing Weather Data for Response 22 of Set 1 | Rikitea
# Processing Weather Data for Response 23 of Set 1 | Chardara
# Processing Weather Data for Response 24 of Set 1 | New Norfolk
# City not Found------SKIP
# Processing Weather Data for Response 25 of Set 1 | Saskylakh
# Processing Weather Data for Response 26 of Set 1 | Ponta do Sol
# Processing Weather Data for Response 27 of Set 1 | Hobart
# Processing Weather Data for Response 28 of Set 1 | Aden
# Processing Weather Data for Response 29 of Set 1 | Rawson
# Processing Weather Data for Response 30 of Set 1 | Dingle
# Processing Weather Data for Response 31 of Set 1 | Mar del Plata
# Processing Weather Data for Response 32 of Set 1 | East London
# Processing Weather Data for Response 33 of Set 1 | Tasiilaq
# Processing Weather Data for Response 34 of Set 1 | Cabo San Lucas
# Processing Weather Data for Response 35 of Set 1 | Verkhoyansk
# Processing Weather Data for Response 36 of Set 1 | Pallasovka
# Processing Weather Data for Response 37 of Set 1 | Mount Gambier
# Processing Weather Data for Response 38 of Set 1 | Makokou
# City not Found------SKIP
# Processing Weather Data for Response 39 of Set 1 | Port Elizabeth
# Processing Weather Data for Response 40 of Set 1 | Kodinsk
# Processing Weather Data for Response 41 of Set 1 | Bunia
# Processing Weather Data for Response 42 of Set 1 | Norman Wells
# Processing Weather Data for Response 43 of Set 1 | Asău
# Processing Weather Data for Response 44 of Set 1 | Torbay
# Processing Weather Data for Response 45 of Set 1 | Honiara
# Processing Weather Data for Response 46 of Set 1 | Lompoc
# Processing Weather Data for Response 47 of Set 1 | Los Llanos de Aridane
# Processing Weather Data for Response 48 of Set 1 | Inhambane
# Processing Weather Data for Response 49 of Set 1 | Atuona
# Processing Weather Data for Response 50 of Set 1 | Walvis Bay
# Processing Weather Data for Response 1 of Set 2 | Hofn
# Processing Weather Data for Response 2 of Set 2 | Cape Town
# Processing Weather Data for Response 3 of Set 2 | Yellowknife
# Processing Weather Data for Response 4 of Set 2 | Ixtapa
# City not Found------SKIP
# Processing Weather Data for Response 5 of Set 2 | Enshi
# Processing Weather Data for Response 6 of Set 2 | Pevek
# Processing Weather Data for Response 7 of Set 2 | Hobyo
# Processing Weather Data for Response 8 of Set 2 | Adrar
# Processing Weather Data for Response 9 of Set 2 | Riberalta
# Processing Weather Data for Response 10 of Set 2 | Zhigansk
# Processing Weather Data for Response 11 of Set 2 | Vaini
# Processing Weather Data for Response 12 of Set 2 | Longyearbyen
# Processing Weather Data for Response 13 of Set 2 | Pilar
# Processing Weather Data for Response 14 of Set 2 | Geraldton
# City not Found------SKIP
# Processing Weather Data for Response 15 of Set 2 | Banjar
# Processing Weather Data for Response 16 of Set 2 | Hithadhoo
# Processing Weather Data for Response 17 of Set 2 | Nabire
# Processing Weather Data for Response 18 of Set 2 | Ilulissat
# Processing Weather Data for Response 19 of Set 2 | Upernavik
# Processing Weather Data for Response 20 of Set 2 | Portland
# City not Found------SKIP
# Processing Weather Data for Response 21 of Set 2 | City of San Pedro
# City not Found------SKIP
# Processing Weather Data for Response 22 of Set 2 | Khovd
# Processing Weather Data for Response 23 of Set 2 | Avarua
# Processing Weather Data for Response 24 of Set 2 | Two Rivers
# Processing Weather Data for Response 25 of Set 2 | Naze
# Processing Weather Data for Response 26 of Set 2 | Naantali
# Processing Weather Data for Response 27 of Set 2 | Jamestown
# Processing Weather Data for Response 28 of Set 2 | Tiksi
# Processing Weather Data for Response 29 of Set 2 | Jumla
# Processing Weather Data for Response 30 of Set 2 | Alcúdia
# City not Found------SKIP
# Processing Weather Data for Response 31 of Set 2 | Isangel
# Processing Weather Data for Response 32 of Set 2 | Mangochi
# Processing Weather Data for Response 33 of Set 2 | Russell
# Processing Weather Data for Response 34 of Set 2 | Oktyabr'skoye
# Processing Weather Data for Response 35 of Set 2 | Kapaa
# Processing Weather Data for Response 36 of Set 2 | Souillac
# City not Found------SKIP
# Processing Weather Data for Response 37 of Set 2 | Teguise
# Processing Weather Data for Response 38 of Set 2 | Talnakh
# Processing Weather Data for Response 39 of Set 2 | Kahului
# Processing Weather Data for Response 40 of Set 2 | ‘Āhuimanu
# Processing Weather Data for Response 41 of Set 2 | Le Port
# Processing Weather Data for Response 42 of Set 2 | Ribeira Grande
# Processing Weather Data for Response 43 of Set 2 | Albany
# Processing Weather Data for Response 44 of Set 2 | Novo Horizonte
# Processing Weather Data for Response 45 of Set 2 | Noumea
# Processing Weather Data for Response 46 of Set 2 | Mahabalipuram
# Processing Weather Data for Response 47 of Set 2 | Pisco
# Processing Weather Data for Response 48 of Set 2 | Umm Kaddadah
# Processing Weather Data for Response 49 of Set 2 | Bjæverskov
# Processing Weather Data for Response 50 of Set 2 | Port Hedland
# Processing Weather Data for Response 1 of Set 3 | Kuala Terengganu
# Processing Weather Data for Response 2 of Set 3 | Barrow
# City not Found------SKIP
# Processing Weather Data for Response 3 of Set 3 | Manggar
# Processing Weather Data for Response 4 of Set 3 | Bluff
# Processing Weather Data for Response 5 of Set 3 | Orange
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 6 of Set 3 | Guerrero Negro
# Processing Weather Data for Response 7 of Set 3 | Hermanus
# Processing Weather Data for Response 8 of Set 3 | Severo-Kuril'sk
# City not Found------SKIP
# Processing Weather Data for Response 9 of Set 3 | Bahía Solano
# Processing Weather Data for Response 10 of Set 3 | Husavik
# Processing Weather Data for Response 11 of Set 3 | Kasungu
# Processing Weather Data for Response 12 of Set 3 | Kutum
# Processing Weather Data for Response 13 of Set 3 | Severomuysk
# Processing Weather Data for Response 14 of Set 3 | Saint-Philippe
# Processing Weather Data for Response 15 of Set 3 | Ukiah
# City not Found------SKIP
# Processing Weather Data for Response 16 of Set 3 | Paluan
# Processing Weather Data for Response 17 of Set 3 | Vercelli
# Processing Weather Data for Response 18 of Set 3 | Touros
# Processing Weather Data for Response 19 of Set 3 | Port Alfred
# Processing Weather Data for Response 20 of Set 3 | Lac du Bonnet
# Processing Weather Data for Response 21 of Set 3 | Tubmanburg
# Processing Weather Data for Response 22 of Set 3 | Hong Kong
# Processing Weather Data for Response 23 of Set 3 | Guaraniaçu
# Processing Weather Data for Response 24 of Set 3 | Ancud
# Processing Weather Data for Response 25 of Set 3 | Acurenam
# Processing Weather Data for Response 26 of Set 3 | Qaanaaq
# Processing Weather Data for Response 27 of Set 3 | Bredasdorp
# Processing Weather Data for Response 28 of Set 3 | Thompson
# Processing Weather Data for Response 29 of Set 3 | Lebu
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 30 of Set 3 | Ostrovnoy
# Processing Weather Data for Response 31 of Set 3 | Nova Olinda do Norte
# Processing Weather Data for Response 32 of Set 3 | Provideniya
# Processing Weather Data for Response 33 of Set 3 | Hongjiang
# Processing Weather Data for Response 34 of Set 3 | Camacha
# Processing Weather Data for Response 35 of Set 3 | Rio Grande
# Processing Weather Data for Response 36 of Set 3 | Manhattan
# Processing Weather Data for Response 37 of Set 3 | Myitkyina
# Processing Weather Data for Response 38 of Set 3 | Mossamedes
# Processing Weather Data for Response 39 of Set 3 | Gornopravdinsk
# Processing Weather Data for Response 40 of Set 3 | Verkh-Chebula
# Processing Weather Data for Response 41 of Set 3 | Ulladulla
# Processing Weather Data for Response 42 of Set 3 | Pánuco
# City not Found------SKIP
# Processing Weather Data for Response 43 of Set 3 | Ishinomaki
# Processing Weather Data for Response 44 of Set 3 | Saint Paul Harbor
# Processing Weather Data for Response 45 of Set 3 | Panabá
# Processing Weather Data for Response 46 of Set 3 | Suoyarvi
# Processing Weather Data for Response 47 of Set 3 | Fort Nelson
# Processing Weather Data for Response 48 of Set 3 | Hawkesbury
# Processing Weather Data for Response 49 of Set 3 | Syracuse
# Processing Weather Data for Response 50 of Set 3 | Severnyy-Kospashskiy
# Processing Weather Data for Response 1 of Set 4 | Manoel Urbano
# Processing Weather Data for Response 2 of Set 4 | Bengkulu
# Processing Weather Data for Response 3 of Set 4 | Valencia
# Processing Weather Data for Response 4 of Set 4 | Kieta
# City not Found------SKIP
# Processing Weather Data for Response 5 of Set 4 | Okha
# Processing Weather Data for Response 6 of Set 4 | Sorong
# Processing Weather Data for Response 7 of Set 4 | Hwange
# Processing Weather Data for Response 8 of Set 4 | Mount Isa
# Processing Weather Data for Response 9 of Set 4 | Crotone
# City not Found------SKIP
# Processing Weather Data for Response 10 of Set 4 | Province of Mantua
# Processing Weather Data for Response 11 of Set 4 | Great Bend
# Processing Weather Data for Response 12 of Set 4 | Tabou
# Processing Weather Data for Response 13 of Set 4 | Corinth
# Processing Weather Data for Response 14 of Set 4 | Turbaná
# Processing Weather Data for Response 15 of Set 4 | Severo-Yeniseyskiy
# Processing Weather Data for Response 16 of Set 4 | Wamba
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 17 of Set 4 | Piskivka
# City not Found------SKIP
# Processing Weather Data for Response 18 of Set 4 | Skjervøy
# Processing Weather Data for Response 19 of Set 4 | Winchester
# Processing Weather Data for Response 20 of Set 4 | Tomatlán
# Processing Weather Data for Response 21 of Set 4 | Mt. Pleasant
# Processing Weather Data for Response 22 of Set 4 | Khatanga
# Processing Weather Data for Response 23 of Set 4 | Eydhafushi
# Processing Weather Data for Response 24 of Set 4 | Tual
# Processing Weather Data for Response 25 of Set 4 | Olafsvik
# City not Found------SKIP
# Processing Weather Data for Response 26 of Set 4 | Muli
# Processing Weather Data for Response 27 of Set 4 | Coquimbo
# Processing Weather Data for Response 28 of Set 4 | Dzerzhinskoye
# Processing Weather Data for Response 29 of Set 4 | Fitii
# Processing Weather Data for Response 30 of Set 4 | Kostanay
# Processing Weather Data for Response 31 of Set 4 | Cherskiy
# Processing Weather Data for Response 32 of Set 4 | Grindavik
# Processing Weather Data for Response 33 of Set 4 | Bantry
# City not Found------SKIP
# Processing Weather Data for Response 34 of Set 4 | Orlik
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 35 of Set 4 | Batamshinskiy
# Processing Weather Data for Response 36 of Set 4 | Buenos Aires
# Processing Weather Data for Response 37 of Set 4 | Chipinge
# Processing Weather Data for Response 38 of Set 4 | Ati
# Processing Weather Data for Response 39 of Set 4 | Saint George
# Processing Weather Data for Response 40 of Set 4 | Thinadhoo
# Processing Weather Data for Response 41 of Set 4 | São Filipe
# Processing Weather Data for Response 42 of Set 4 | Hondomachi-hondo
# Processing Weather Data for Response 43 of Set 4 | Praia
# Processing Weather Data for Response 44 of Set 4 | Chokurdakh
# City not Found------SKIP
# Processing Weather Data for Response 45 of Set 4 | Lorengau
# Processing Weather Data for Response 46 of Set 4 | Hasaki
# Processing Weather Data for Response 47 of Set 4 | Pangnirtung
# Processing Weather Data for Response 48 of Set 4 | Praia
# Processing Weather Data for Response 49 of Set 4 | Aykhal
# Processing Weather Data for Response 50 of Set 4 | Dalton
# Processing Weather Data for Response 1 of Set 5 | Xapuri
# Processing Weather Data for Response 2 of Set 5 | Puerto Ayora
# Processing Weather Data for Response 3 of Set 5 | Boende
# Processing Weather Data for Response 4 of Set 5 | Atasū
# Processing Weather Data for Response 5 of Set 5 | Likasi
# Processing Weather Data for Response 6 of Set 5 | Codrington
# City not Found------SKIP
# Processing Weather Data for Response 7 of Set 5 | Pangkalanbuun
# Processing Weather Data for Response 8 of Set 5 | Deputatsky
# Processing Weather Data for Response 9 of Set 5 | Āsosa
# Processing Weather Data for Response 10 of Set 5 | Rakiv Lis
# Processing Weather Data for Response 11 of Set 5 | San Juan
# Processing Weather Data for Response 12 of Set 5 | Kavieng
# Processing Weather Data for Response 13 of Set 5 | Sur
# Processing Weather Data for Response 14 of Set 5 | Tataouine
# Processing Weather Data for Response 15 of Set 5 | Petropavlovsk-Kamchatskiy
# Processing Weather Data for Response 16 of Set 5 | Buala
# Processing Weather Data for Response 17 of Set 5 | Nansio
# Processing Weather Data for Response 18 of Set 5 | Tashtyp
# Processing Weather Data for Response 19 of Set 5 | Puerto del Rosario
# Processing Weather Data for Response 20 of Set 5 | Port Moresby
# Processing Weather Data for Response 21 of Set 5 | Steamboat Springs
# Processing Weather Data for Response 22 of Set 5 | Waingapu
# Processing Weather Data for Response 23 of Set 5 | Bouna
# City not Found------SKIP
# Processing Weather Data for Response 24 of Set 5 | Aripuanã
# Processing Weather Data for Response 25 of Set 5 | Acapulco de Juárez
# City not Found------SKIP
# Processing Weather Data for Response 26 of Set 5 | Buritis
# Processing Weather Data for Response 27 of Set 5 | Kabare
# Processing Weather Data for Response 28 of Set 5 | Bend
# Processing Weather Data for Response 29 of Set 5 | Padang
# Processing Weather Data for Response 30 of Set 5 | Broken Hill
# Processing Weather Data for Response 31 of Set 5 | Lerwick
# Processing Weather Data for Response 32 of Set 5 | Aklavik
# Processing Weather Data for Response 33 of Set 5 | Iquitos
# Processing Weather Data for Response 34 of Set 5 | Kalmunai
# Processing Weather Data for Response 35 of Set 5 | Funehikimachi-funehiki
# Processing Weather Data for Response 36 of Set 5 | Chui
# Processing Weather Data for Response 37 of Set 5 | George Town
# Processing Weather Data for Response 38 of Set 5 | Haines Junction
# Processing Weather Data for Response 39 of Set 5 | Kerman
# Processing Weather Data for Response 40 of Set 5 | Vao
# City not Found------SKIP
# Processing Weather Data for Response 41 of Set 5 | Liverpool
# Processing Weather Data for Response 42 of Set 5 | Palmer
# Processing Weather Data for Response 43 of Set 5 | Betioky
# Processing Weather Data for Response 44 of Set 5 | Kathu
# Processing Weather Data for Response 45 of Set 5 | Manacapuru
# Processing Weather Data for Response 46 of Set 5 | Ottawa
# Processing Weather Data for Response 47 of Set 5 | Kenora
# City not Found------SKIP
# Processing Weather Data for Response 48 of Set 5 | Yar-Sale
# Processing Weather Data for Response 49 of Set 5 | Poreč
# Processing Weather Data for Response 50 of Set 5 | Beringovskiy
# Processing Weather Data for Response 1 of Set 6 | Vila
# Processing Weather Data for Response 2 of Set 6 | Liuhe
# Processing Weather Data for Response 3 of Set 6 | Nanortalik
# Processing Weather Data for Response 4 of Set 6 | Chicama
# Processing Weather Data for Response 5 of Set 6 | Sulangan
# Processing Weather Data for Response 6 of Set 6 | Honningsvåg
# Processing Weather Data for Response 7 of Set 6 | Fairbanks
# Processing Weather Data for Response 8 of Set 6 | Kristiansund
# Processing Weather Data for Response 9 of Set 6 | Payson
# Processing Weather Data for Response 10 of Set 6 | Cayenne
# Processing Weather Data for Response 11 of Set 6 | Datong
# Processing Weather Data for Response 12 of Set 6 | Kisangani
# Processing Weather Data for Response 13 of Set 6 | Caravelas
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 14 of Set 6 | Yārāda
# Processing Weather Data for Response 15 of Set 6 | Bathsheba
# Processing Weather Data for Response 16 of Set 6 | Bara
# Processing Weather Data for Response 17 of Set 6 | Kyren
# Processing Weather Data for Response 18 of Set 6 | Kanniyākumāri
# City not Found------SKIP
# Processing Weather Data for Response 19 of Set 6 | Fukuechō
# Processing Weather Data for Response 20 of Set 6 | Cururupu
# Processing Weather Data for Response 21 of Set 6 | Boyolangu
# Processing Weather Data for Response 22 of Set 6 | Belyy Yar
# Processing Weather Data for Response 23 of Set 6 | Turbat
# Processing Weather Data for Response 24 of Set 6 | Tautira
# Processing Weather Data for Response 25 of Set 6 | Banda Aceh
# Processing Weather Data for Response 26 of Set 6 | Yeppoon
# Processing Weather Data for Response 27 of Set 6 | Saint-Pierre
# Processing Weather Data for Response 28 of Set 6 | Iqaluit
# Processing Weather Data for Response 29 of Set 6 | Tuatapere
# Processing Weather Data for Response 30 of Set 6 | Bethel
# Processing Weather Data for Response 31 of Set 6 | Santa Maria
# Processing Weather Data for Response 32 of Set 6 | Lock Haven
# Processing Weather Data for Response 33 of Set 6 | Bilma
# Processing Weather Data for Response 34 of Set 6 | Omboué
# Processing Weather Data for Response 35 of Set 6 | Kavaratti
# Processing Weather Data for Response 36 of Set 6 | Moche
# Processing Weather Data for Response 37 of Set 6 | Nelson Bay
# Processing Weather Data for Response 38 of Set 6 | Dingzhou
# Processing Weather Data for Response 39 of Set 6 | Carnarvon
# Processing Weather Data for Response 40 of Set 6 | Arrondissement de Limoges
# City not Found------SKIP
# Processing Weather Data for Response 41 of Set 6 | Lundazi
# Processing Weather Data for Response 42 of Set 6 | Manado
# Processing Weather Data for Response 43 of Set 6 | Havøysund
# Processing Weather Data for Response 44 of Set 6 | Constitución
# Processing Weather Data for Response 45 of Set 6 | Fredericksburg
# Processing Weather Data for Response 46 of Set 6 | Kollo
# Processing Weather Data for Response 47 of Set 6 | Arona
# Processing Weather Data for Response 48 of Set 6 | Mehamn
# Processing Weather Data for Response 49 of Set 6 | Chapais
# Processing Weather Data for Response 50 of Set 6 | Westport
# Processing Weather Data for Response 1 of Set 7 | Saldanha
# Processing Weather Data for Response 2 of Set 7 | Cidreira
# Processing Weather Data for Response 3 of Set 7 | Kuching
# Processing Weather Data for Response 4 of Set 7 | Tambo
# Processing Weather Data for Response 5 of Set 7 | Stafford
# Processing Weather Data for Response 6 of Set 7 | Taoudenni
# Processing Weather Data for Response 7 of Set 7 | Castro
# City not Found------SKIP
# Processing Weather Data for Response 8 of Set 7 | Mīnāb
# Processing Weather Data for Response 9 of Set 7 | Nīmbāhera
# Processing Weather Data for Response 10 of Set 7 | Samarai
# Processing Weather Data for Response 11 of Set 7 | Yenagoa
# Processing Weather Data for Response 12 of Set 7 | Bada
# Processing Weather Data for Response 13 of Set 7 | Matata
# Processing Weather Data for Response 14 of Set 7 | Prince Rupert
# Processing Weather Data for Response 15 of Set 7 | Vardø
# Processing Weather Data for Response 16 of Set 7 | Salalah
# Processing Weather Data for Response 17 of Set 7 | La Ronge
# City not Found------SKIP
# Processing Weather Data for Response 18 of Set 7 | Baoqing
# Processing Weather Data for Response 19 of Set 7 | Georgiyevka
# Processing Weather Data for Response 20 of Set 7 | Margate
# Processing Weather Data for Response 21 of Set 7 | Santa Cruz
# Processing Weather Data for Response 22 of Set 7 | San Jerónimo
# Processing Weather Data for Response 23 of Set 7 | Opuwo
# Processing Weather Data for Response 24 of Set 7 | Batié
# Processing Weather Data for Response 25 of Set 7 | Bagdarin
# Processing Weather Data for Response 26 of Set 7 | Lüshunkou
# City not Found------SKIP
# Processing Weather Data for Response 27 of Set 7 | Dunedin
# Processing Weather Data for Response 28 of Set 7 | Tocopilla
# Processing Weather Data for Response 29 of Set 7 | Qaqortoq
# Processing Weather Data for Response 30 of Set 7 | San Patricio
# Processing Weather Data for Response 31 of Set 7 | Tønder
# Processing Weather Data for Response 32 of Set 7 | Vila Franca do Campo
# Processing Weather Data for Response 33 of Set 7 | Buluang
# Processing Weather Data for Response 34 of Set 7 | Sakakah
# Processing Weather Data for Response 35 of Set 7 | Sassandra
# City not Found------SKIP
# Processing Weather Data for Response 36 of Set 7 | Te Anau
# Processing Weather Data for Response 37 of Set 7 | Yuncheng
# Processing Weather Data for Response 38 of Set 7 | Lázaro Cárdenas
# Processing Weather Data for Response 39 of Set 7 | Río Gallegos
# Processing Weather Data for Response 40 of Set 7 | College
# Processing Weather Data for Response 41 of Set 7 | Fortuna
# Processing Weather Data for Response 42 of Set 7 | Luchegorsk
# Processing Weather Data for Response 43 of Set 7 | Nyurba
# Processing Weather Data for Response 44 of Set 7 | Killybegs
# Processing Weather Data for Response 45 of Set 7 | Bozdar Wada
# Processing Weather Data for Response 46 of Set 7 | Rāwah
# Processing Weather Data for Response 47 of Set 7 | Fare
# Processing Weather Data for Response 48 of Set 7 | Kumul
# Processing Weather Data for Response 49 of Set 7 | Huarmey
# Processing Weather Data for Response 50 of Set 7 | Ossora
# Processing Weather Data for Response 1 of Set 8 | Biu
# Processing Weather Data for Response 2 of Set 8 | Cockburn Town
# Processing Weather Data for Response 3 of Set 8 | Port Lincoln
# Processing Weather Data for Response 4 of Set 8 | Nautla
# Processing Weather Data for Response 5 of Set 8 | Tamandaré
# Processing Weather Data for Response 6 of Set 8 | Xining
# Processing Weather Data for Response 7 of Set 8 | Vanavara
# Processing Weather Data for Response 8 of Set 8 | Imuris
# Processing Weather Data for Response 9 of Set 8 | Lata
# Processing Weather Data for Response 10 of Set 8 | Road Town
# Processing Weather Data for Response 11 of Set 8 | Bilibino
# Processing Weather Data for Response 12 of Set 8 | Port Macquarie
# Processing Weather Data for Response 13 of Set 8 | Maridi
# City not Found------SKIP
# Processing Weather Data for Response 14 of Set 8 | Kez
# Processing Weather Data for Response 15 of Set 8 | Trincomalee
# Processing Weather Data for Response 16 of Set 8 | Atkinson
# Processing Weather Data for Response 17 of Set 8 | Barinas
# Processing Weather Data for Response 18 of Set 8 | Bukachacha
# Processing Weather Data for Response 19 of Set 8 | Lavrentiya
# Processing Weather Data for Response 20 of Set 8 | Mabai
# Processing Weather Data for Response 21 of Set 8 | Umluj
# Processing Weather Data for Response 22 of Set 8 | Sisimiut
# City not Found------SKIP
# Processing Weather Data for Response 23 of Set 8 | Sitka
# Processing Weather Data for Response 24 of Set 8 | Lagoa
# Processing Weather Data for Response 25 of Set 8 | Reyes
# Processing Weather Data for Response 26 of Set 8 | Wenshang
# Processing Weather Data for Response 27 of Set 8 | Jackson
# Processing Weather Data for Response 28 of Set 8 | Kirovskiy
# Processing Weather Data for Response 29 of Set 8 | Hambantota
# Processing Weather Data for Response 30 of Set 8 | Kruisfontein
# Processing Weather Data for Response 31 of Set 8 | Batagay
# Processing Weather Data for Response 32 of Set 8 | Adrano
# Processing Weather Data for Response 33 of Set 8 | Northam
# Processing Weather Data for Response 34 of Set 8 | Harper
# Processing Weather Data for Response 35 of Set 8 | Guadalupe y Calvo
# Processing Weather Data for Response 36 of Set 8 | Azanka
# Processing Weather Data for Response 37 of Set 8 | Matagami
# Processing Weather Data for Response 38 of Set 8 | Bezhanitsy
# Processing Weather Data for Response 39 of Set 8 | Lishui
# City not Found------SKIP
# Processing Weather Data for Response 40 of Set 8 | Esperance
# Processing Weather Data for Response 41 of Set 8 | Farmington
# Processing Weather Data for Response 42 of Set 8 | Roald
# City not Found------SKIP
# Processing Weather Data for Response 43 of Set 8 | Gresham
# City not Found------SKIP
# Processing Weather Data for Response 44 of Set 8 | Anadyr
# City not Found------SKIP
# Processing Weather Data for Response 45 of Set 8 | Saquarema
# Processing Weather Data for Response 46 of Set 8 | Lichinga
# Processing Weather Data for Response 47 of Set 8 | Osmeña
# Processing Weather Data for Response 48 of Set 8 | Okhotsk
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 49 of Set 8 | Manokwari
# Processing Weather Data for Response 50 of Set 8 | Thunder Bay
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 1 of Set 9 | Dakoro
# Processing Weather Data for Response 2 of Set 9 | Kurumkan
# Processing Weather Data for Response 3 of Set 9 | Udachny
# Processing Weather Data for Response 4 of Set 9 | Aitape
# Processing Weather Data for Response 5 of Set 9 | Dhidhdhoo
# Processing Weather Data for Response 6 of Set 9 | Puerto Escondido
# Processing Weather Data for Response 7 of Set 9 | Kiryat Gat
# Processing Weather Data for Response 8 of Set 9 | Puerto Baquerizo Moreno
# Processing Weather Data for Response 9 of Set 9 | Mahébourg
# Processing Weather Data for Response 10 of Set 9 | Iglesias
# City not Found------SKIP
# Processing Weather Data for Response 11 of Set 9 | Gamba
# Processing Weather Data for Response 12 of Set 9 | Bundaberg
# Processing Weather Data for Response 13 of Set 9 | Harbour Breton
# Processing Weather Data for Response 14 of Set 9 | Maningrida
# Processing Weather Data for Response 15 of Set 9 | Bushehr
# City not Found------SKIP
# Processing Weather Data for Response 16 of Set 9 | Estrela
# Processing Weather Data for Response 17 of Set 9 | Nuuk
# Processing Weather Data for Response 18 of Set 9 | Muzaffarabad
# Processing Weather Data for Response 19 of Set 9 | Simpang
# Processing Weather Data for Response 20 of Set 9 | Bulungu
# Processing Weather Data for Response 21 of Set 9 | Evensk
# Processing Weather Data for Response 22 of Set 9 | Champerico
# Processing Weather Data for Response 23 of Set 9 | Ndago
# Processing Weather Data for Response 24 of Set 9 | San Quintín
# Processing Weather Data for Response 25 of Set 9 | Lagos
# Processing Weather Data for Response 26 of Set 9 | Beloha
# Processing Weather Data for Response 27 of Set 9 | São José da Coroa Grande
# Processing Weather Data for Response 28 of Set 9 | Paamiut
# Processing Weather Data for Response 29 of Set 9 | Aksarka
# Processing Weather Data for Response 30 of Set 9 | Teahupoo
# Processing Weather Data for Response 31 of Set 9 | Sarany
# City not Found------SKIP
# Processing Weather Data for Response 32 of Set 9 | Devils Lake
# Processing Weather Data for Response 33 of Set 9 | Vila Velha
# Processing Weather Data for Response 34 of Set 9 | Ussuriysk
# Processing Weather Data for Response 35 of Set 9 | Dudinka
# Processing Weather Data for Response 36 of Set 9 | Abéché
# Processing Weather Data for Response 37 of Set 9 | Broome
# Processing Weather Data for Response 38 of Set 9 | Esfarāyen
# Processing Weather Data for Response 39 of Set 9 | Stephenville
# Processing Weather Data for Response 40 of Set 9 | São José de Ribamar
# Processing Weather Data for Response 41 of Set 9 | Imbituba
# Processing Weather Data for Response 42 of Set 9 | Pangai
# Processing Weather Data for Response 43 of Set 9 | Ternate
# Processing Weather Data for Response 44 of Set 9 | Sabha
# Processing Weather Data for Response 45 of Set 9 | Aransas Pass
# Processing Weather Data for Response 46 of Set 9 | Zwiesel
# Processing Weather Data for Response 47 of Set 9 | Mórrope
# Processing Weather Data for Response 48 of Set 9 | Lake Charles
# Processing Weather Data for Response 49 of Set 9 | Agüimes
# Processing Weather Data for Response 50 of Set 9 | São João da Barra
# Processing Weather Data for Response 1 of Set 10 | Saint-Joseph
# Processing Weather Data for Response 2 of Set 10 | Guangzhou
# Processing Weather Data for Response 3 of Set 10 | Antofagasta
# Processing Weather Data for Response 4 of Set 10 | Gubkinskiy
# Processing Weather Data for Response 5 of Set 10 | Lumphat
# Processing Weather Data for Response 6 of Set 10 | Coihueco
# Processing Weather Data for Response 7 of Set 10 | La Primavera
# Processing Weather Data for Response 8 of Set 10 | Port Blair
# Processing Weather Data for Response 9 of Set 10 | Springbok
# Processing Weather Data for Response 10 of Set 10 | Ibb
# Processing Weather Data for Response 11 of Set 10 | Seymchan
# Processing Weather Data for Response 12 of Set 10 | Kamari
# Processing Weather Data for Response 13 of Set 10 | Tessalit
# City not Found------SKIP
# Processing Weather Data for Response 14 of Set 10 | Tura
# Processing Weather Data for Response 15 of Set 10 | Morinville
# Processing Weather Data for Response 16 of Set 10 | Acarí
# Processing Weather Data for Response 17 of Set 10 | Sola
# Processing Weather Data for Response 18 of Set 10 | Tūkrah
# Processing Weather Data for Response 19 of Set 10 | Brae
# Processing Weather Data for Response 20 of Set 10 | Taicheng
# City not Found------SKIP
# Processing Weather Data for Response 21 of Set 10 | Anloga
# Processing Weather Data for Response 22 of Set 10 | Kovūr
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 23 of Set 10 | Nānākuli
# Processing Weather Data for Response 24 of Set 10 | Port Said
# Processing Weather Data for Response 25 of Set 10 | Faanui
# City not Found------SKIP
# Processing Weather Data for Response 26 of Set 10 | Kidal
# Processing Weather Data for Response 27 of Set 10 | Ayna
# Processing Weather Data for Response 28 of Set 10 | Sarandi
# Processing Weather Data for Response 29 of Set 10 | Piaçabuçu
# Processing Weather Data for Response 30 of Set 10 | Coahuayana Viejo
# Processing Weather Data for Response 31 of Set 10 | Storebø
# City not Found------SKIP
# Processing Weather Data for Response 32 of Set 10 | Shingū
# Processing Weather Data for Response 33 of Set 10 | Hov
# Processing Weather Data for Response 34 of Set 10 | Fuerte
# Processing Weather Data for Response 35 of Set 10 | Emerald
# Processing Weather Data for Response 36 of Set 10 | Christchurch
# Processing Weather Data for Response 37 of Set 10 | Skeldon
# Processing Weather Data for Response 38 of Set 10 | Nuevitas
# Processing Weather Data for Response 39 of Set 10 | Visby
# City not Found------SKIP
# Processing Weather Data for Response 40 of Set 10 | Luau
# Processing Weather Data for Response 41 of Set 10 | Barcelos
# Processing Weather Data for Response 42 of Set 10 | Santa Cruz Cabrália
# Processing Weather Data for Response 43 of Set 10 | Palu
# Processing Weather Data for Response 44 of Set 10 | Haverfordwest
# Processing Weather Data for Response 45 of Set 10 | Gizo Government Station
# Processing Weather Data for Response 46 of Set 10 | Līsakovsk
# Processing Weather Data for Response 47 of Set 10 | Tinskoy
# City not Found------SKIP
# Processing Weather Data for Response 48 of Set 10 | Soverato Marina
# Processing Weather Data for Response 49 of Set 10 | Rome
# Processing Weather Data for Response 50 of Set 10 | Fort-Shevchenko
# Processing Weather Data for Response 1 of Set 11 | Tazovsky
# Processing Weather Data for Response 2 of Set 11 | Kayes
# Processing Weather Data for Response 3 of Set 11 | Arrondissement de Bar-le-Duc
# Processing Weather Data for Response 4 of Set 11 | Lyuban'
# Processing Weather Data for Response 5 of Set 11 | Bandarbeyla
# Processing Weather Data for Response 6 of Set 11 | Teano
# Processing Weather Data for Response 7 of Set 11 | Normandin
# City not Found------SKIP
# Processing Weather Data for Response 8 of Set 11 | Kamenka
# Processing Weather Data for Response 9 of Set 11 | La Unión
# Processing Weather Data for Response 10 of Set 11 | La Roda
# Processing Weather Data for Response 11 of Set 11 | Paka
# Processing Weather Data for Response 12 of Set 11 | Grand Gaube
# Processing Weather Data for Response 13 of Set 11 | Half Moon Bay
# Processing Weather Data for Response 14 of Set 11 | Ust-Nera
# City not Found------SKIP
# Processing Weather Data for Response 15 of Set 11 | Aksu
# Processing Weather Data for Response 16 of Set 11 | Turinsk
# City not Found------SKIP
# City not Found------SKIP
# City not Found------SKIP
# Processing Weather Data for Response 17 of Set 11 | Nanga Eboko
# Processing Weather Data for Response 18 of Set 11 | Beyneu
# City not Found------SKIP
# Processing Weather Data for Response 19 of Set 11 | Masallātah
# Processing Weather Data for Response 20 of Set 11 | Azángaro
# Processing Weather Data for Response 21 of Set 11 | Karpogory
# Processing Weather Data for Response 22 of Set 11 | Alofi
# Processing Weather Data for Response 23 of Set 11 | Auki
# Processing Weather Data for Response 24 of Set 11 | Vestmannaeyjar
# City not Found------SKIP
# Processing Weather Data for Response 25 of Set 11 | Prainha
# Processing Weather Data for Response 26 of Set 11 | Malpe
# Processing Weather Data for Response 27 of Set 11 | Dickinson
# Processing Weather Data for Response 28 of Set 11 | Tongchuanshi
# Processing Weather Data for Response 29 of Set 11 | Nortelândia
# Processing Weather Data for Response 30 of Set 11 | Vanimo
# Processing Weather Data for Response 31 of Set 11 | Agbor
# City not Found------SKIP
# Processing Weather Data for Response 32 of Set 11 | Gimli
# City not Found------SKIP
# Processing Weather Data for Response 33 of Set 11 | Machalí
# City not Found------SKIP
# Processing Weather Data for Response 34 of Set 11 | Hellange
# Processing Weather Data for Response 35 of Set 11 | Berlevåg
# Processing Weather Data for Response 36 of Set 11 | Kaihua
# Processing Weather Data for Response 37 of Set 11 | Mae Tha
# Processing Weather Data for Response 38 of Set 11 | Morant Bay
# Processing Weather Data for Response 39 of Set 11 | Port Hardy
# Processing Weather Data for Response 40 of Set 11 | Dampit
# Processing Weather Data for Response 41 of Set 11 | Eirunepé
# Processing Weather Data for Response 42 of Set 11 | Krasnosel'kup
# Processing Weather Data for Response 43 of Set 11 | Canterbury
# Processing Weather Data for Response 44 of Set 11 | Ayr
# Processing Weather Data for Response 45 of Set 11 | União
# Processing Weather Data for Response 46 of Set 11 | Zhuhai
# Processing Weather Data for Response 47 of Set 11 | Sinnamary
# Processing Weather Data for Response 48 of Set 11 | Yüksekova
# Processing Weather Data for Response 49 of Set 11 | Weyburn
# City not Found------SKIP
# Processing Weather Data for Response 50 of Set 11 | Popondetta
# Processing Weather Data for Response 1 of Set 12 | Ardusat
# Processing Weather Data for Response 2 of Set 12 | Port Hawkesbury
# Processing Weather Data for Response 3 of Set 12 | Ambilobe
# Processing Weather Data for Response 4 of Set 12 | Anamur
# Processing Weather Data for Response 5 of Set 12 | Jining
# Processing Weather Data for Response 6 of Set 12 | Sørland
# Processing Weather Data for Response 7 of Set 12 | Guía de Isora
# Processing Weather Data for Response 8 of Set 12 | High Prairie
# Processing Weather Data for Response 9 of Set 12 | Tiznit Province
# Processing Weather Data for Response 10 of Set 12 | Konya Province
# Processing Weather Data for Response 11 of Set 12 | Zaysan
# City not Found------SKIP
# Processing Weather Data for Response 12 of Set 12 | San Bartolomé de Tirajana
# Processing Weather Data for Response 13 of Set 12 | Kushiro
# --------------------
#          Data Retrieval Finished
#          --------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#clean df
ctweather_df['Max Temp']= ctweather_df['Max Temp'].replace('',np.nan)
ctweather_df = ctweather_df.dropna()

#save df to csv
ctweather_df.to_csv("CityWeatherData.csv")

ctweather_df.head()
# Out:
#            City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0  quatre cocos         75      MU  1586649007       83 -20.21   57.76
# 1    butaritari         88      KI  1586648915       74   3.07  172.79
# 2        narsaq        100      GL  1586648870       39  60.92  -46.05
# 3   tuktoyaktuk         20      CA  1586649008       84  69.45 -133.04
# 5   clyde river         20      CA  1586649008       84  70.47  -68.59
#
#    Max Temp Windspeed
# 0     75.99      5.82
# 1     84.04     10.36
# 2     46.40     38.03
# 3      6.80     11.41
# 5      5.00     10.29

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
sns.set_style("darkgrid")
fig,ax = plt.subplots(figsize=(10,8))
ax.scatter(ctweather_df['Lat'], ctweather_df['Max Temp'], c='blue', alpha=.6, linewidth=1, edgecolor='black')
ax.set_xlim(-90,90)
ax.set_ylim(min(ctweather_df['Max Temp'])-10,max(ctweather_df['Max Temp'])+10)
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Latitude vs Max Temperature")

plt.savefig("LatvTemp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
sns.set_style("darkgrid")
fig,ax = plt.subplots(figsize=(10,8))
ax.scatter(ctweather_df['Lat'], ctweather_df['Humidity'], c='blue', alpha=.6, linewidth=1, edgecolor='black')
ax.set_xlim(-90,90)
ax.set_ylim(min(ctweather_df['Humidity'])-10,max(ctweather_df['Humidity'])+10)
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title("City Latitude vs Humidity")

plt.savefig("LatvHum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
sns.set_style("darkgrid")
fig,ax = plt.subplots(figsize=(10,8))
ax.scatter(ctweather_df['Lat'], ctweather_df['Cloudiness'], c='blue', alpha=.6, linewidth=1, edgecolor='black')
ax.set_xlim(-90,90)
ax.set_ylim(min(ctweather_df['Cloudiness'])-10,max(ctweather_df['Cloudiness'])+10)
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness")
ax.set_title("City Latitude vs Cloudiness")

plt.savefig("LatvCloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
sns.set_style("darkgrid")
fig,ax = plt.subplots(figsize=(10,8))
ax.scatter(ctweather_df['Lat'], ctweather_df['Windspeed'], c='blue', alpha=.6, linewidth=1, edgecolor='black')
ax.set_xlim(-90,90)
ax.set_ylim(min(ctweather_df['Windspeed']-5),max(ctweather_df['Windspeed'])+10)
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed")
ax.set_title("City Latitude vs Wind Speed")

plt.savefig("LatvWind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
